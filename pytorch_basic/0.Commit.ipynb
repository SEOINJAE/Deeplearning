# %%
cd/content/drive/MyDrive/Git_link/Deeplearning/pytorch_basic
# Out:
# /content/drive/MyDrive/Git_link/Deeplearning/pytorch_basic

# %%
# !git config --global user.email "injaeda7@gmail.com"
# !git config --global user.name "SEOINJAE"

# %%
# !git pull
# Out:
# Already up to date.

# %%
# !git add .

# %%
# !git commit -m "chapter 8 done"
# Out:
# [master 9d0c207] chapter 8 done
#  3 files changed, 3 insertions(+), 3 deletions(-)
#  rewrite pytorch_basic/0.Commit.ipynb (67%)
#  rewrite pytorch_basic/8.Bi-LSTM.ipynb (89%)
#  rewrite pytorch_basic/9.GRU.ipynb (96%)

# %%
# !git push
# Out:
# Counting objects: 6, done.
# Delta compression using up to 2 threads.
# Compressing objects: 100% (6/6), done.
# Writing objects: 100% (6/6), 469.94 KiB | 9.21 MiB/s, done.
# Total 6 (delta 3), reused 0 (delta 0)
# remote: Resolving deltas: 100% (3/3), completed with 3 local objects.
# To https://github.com/SEOINJAE/Deeplearning.git
#    c872753..9d0c207  master -> master
