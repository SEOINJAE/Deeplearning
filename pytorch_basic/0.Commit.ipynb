# %%
cd/content/drive/MyDrive/Git_link/Deeplearning/pytorch_basic
# Out:
# /content/drive/MyDrive/Git_link/Deeplearning/pytorch_basic

# %%
# !git config --global user.email "injaeda7@gmail.com"
# !git config --global user.name "SEOINJAE"

# %%
# !git pull
# Out:
# Already up to date.

# %%
# !git add .

# %%
# !git commit -m "chapter 7 done"
# Out:
# [master df30458] chapter 7 done
#  3 files changed, 3 insertions(+), 2 deletions(-)
#  create mode 100644 pytorch_basic/0.Commit.ipynb
#  rewrite pytorch_basic/7.LSTM.ipynb (97%)

# %%
# !git push
# Out:
# Counting objects: 6, done.
# Delta compression using up to 2 threads.
# Compressing objects: 100% (6/6), done.
# Writing objects: 100% (6/6), 79.93 KiB | 2.66 MiB/s, done.
# Total 6 (delta 2), reused 0 (delta 0)
# remote: Resolving deltas: 100% (2/2), completed with 2 local objects.
# To https://github.com/SEOINJAE/Deeplearning.git
#    6fe04be..df30458  master -> master
