# %% [markdown]
# # 4. 인공신경망
# ## 4.2 최적화 기법

# %%
import torch
import torchvision

# %%
model = torchvision.models.resnet18(pretrained=False)

# %% [markdown]
# ### 1) SGD

# %%
optimizer = torch.optim.SGD(model.parameters(), lr=0.01)

# %% [markdown]
# ### 2) Momentum

# %%
optimizer = torch.optim.SGD(model.parameters(), lr=0.01, momentum=0.9)

# %% [markdown]
# ### 3) Adam

# %%
#Adam을 사용할때는 스케줄링을 사용하지 않는다. 기본적으로 아담내에서는 러닝레이트를 조정하는 기능을 갖고 있다.
optimizer = torch.optim.Adam(model.parameters(), lr=0.01)

# %% [markdown]
# ### 4) Scheduling

# %%
optimizer = torch.optim.SGD(model.parameters(), lr=0.1, momentum=0.9)
#step_size = 30은 30epoch마다 러닝레이트를 조정한다는 의미이다.
#gamma=0.1은 옵티마이저에 선언된 러닝레이트에, 스케줄러에 선언된 스텝사이즈만큼의 에폭이 실행된 후 감마에 선언된 값이 러닝레이트와 곱해져서 다음 스탭의 러닝레이트로 사용된다.
scheduler = torch.optim.lr_scheduler.StepLR(optimizer, step_size=30, gamma=0.1)

# %%
... 중략 ...

for epoch in range(400): 
    running_loss = 0.0
    for data in trainloader: 
        inputs, values = data 
        optimizer.zero_grad() 
        outputs = model(inputs) 
        loss = criterion(outputs, values) 
        loss.backward() 
        optimizer.step() 
        
        ... 중략 ...
    
    scheduler.step() # 스케줄링을 통한 학습률 조정

# %% [markdown]
# ## Commit

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
cd/content/drive/MyDrive/Git_link/Deeplearning/pytorch_basic
# Out:
# /content/drive/MyDrive/Git_link/Deeplearning/pytorch_basic

# %%
# !git config --global user.email "injaeda7@gmail.com"
# !git config --global user.name "SEOINJAE"

# %%
# !git pull
# Out:
# Already up to date.

# %%
# !git add .

# %%
# !git commit -m "chapter 2 done"
# Out:
# [master f3afc24] chapter 2 done
#  2 files changed, 2 insertions(+), 1 deletion(-)
#  rewrite "pytorch_basic/1.Neural Networks(\341\204\207\341\205\251\341\204\211\341\205\263\341\204\220\341\205\245\341\206\253 \341\204\214\341\205\265\341\206\270\341\204\200\341\205\241\341\206\271 \341\204\213\341\205\250\341\204\216\341\205\263\341\206\250).ipynb" (91%)
#  create mode 100644 pytorch_basic/2.Optimizers.ipynb

# %%
# !git push
# Out:
# Counting objects: 5, done.
# Delta compression using up to 2 threads.
# Compressing objects: 100% (4/4), done.
# Writing objects: 100% (5/5), 45.82 KiB | 5.73 MiB/s, done.
# Total 5 (delta 1), reused 0 (delta 0)
# remote: Resolving deltas: 100% (1/1), completed with 1 local object.
# To https://github.com/SEOINJAE/Deeplearning.git
#    4e9b607..f3afc24  master -> master
