# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
cd/content/drive/MyDrive/Git_link/Deeplearning/pytorch_basic
# Out:
# /content/drive/MyDrive/Git_link/Deeplearning/pytorch_basic

# %%
# !git clone https://SEOINJAE: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@github.com/SEOINJAE/Deeplearning.git
# Out:
# Cloning into 'Deeplearning'...
# ...

# %%
# !git config --global user.email "injaeda7@gmial.com"
# !git config --global user.name "SEOINJAE"

# %%
print("hellow world!")
# Out:
# hellow world!

# %%
# !git add .

# %%
# !git commit -m "test colab commit"
# Out:
# On branch master
# Your branch is up to date with 'origin/master'.
#
# Changes not staged for commit:
# 	deleted:    "../4-1.Neural Networks(\341\204\207\341\205\251\341\204\211\341\205\263\341\204\220\341\205\245\341\206\253 \341\204\214\341\205\265\341\206\270\341\204\200\341\205\241\341\206\271 \341\204\213\341\205\250\341\204\216\341\205\263\341\206\250).ipynb"
#
# Untracked files:
# 	./
#
# no changes added to commit
