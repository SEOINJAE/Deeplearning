# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/gdrive

# %%
cd/content/drive/My Drive/Git_Pytorch/Deeplearning/pytorch/cifar10
# Out:
# /content/gdrive/My Drive/deeplearningbro/pytorch/cifar10

# %%
# !python main.py

# %%
# !python main.py --train eval --pretrained ./results/resnet18_best.pth
# Out:
# Namespace(batch_size=128, epoch=101, l2=0.0001, lr=0.001, model_name='resnet18', pretrained='./results/resnet18_best.pth', train='eval')
# Files already downloaded and verified
# Files already downloaded and verified
# Completed loading your datasets.
# Completed you pretrained model.
# Completed loading your network.
#  Train Accuracy: 94.104, Test Accuraccy: 89.28
